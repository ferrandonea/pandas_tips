# %%
# %matplotlib inline
import pandas as pd
import numpy as np

from IPython.display import display

# %%
pd.options.display.min_rows = 20 # para que no lesee

# %% [markdown]
# # Datos

# %%
#datasets de autos en EEUU, para cada nuevo modelo nuevo tienen una tonelada de datos
dataset = 'https://github.com/mattharrison/datasets/raw/master/data/vehicles.csv.zip'

#leyendo
autos = pd.read_csv(dataset)
# Out:
# /var/folders/w6/2grt96qn39vgm51r4hz21bz40000gn/T/ipykernel_2169/1438520860.py:5: DtypeWarning: Columns (68,70,71,72,73,74,76,79) have mixed types. Specify dtype option on import or set low_memory=False.
#   autos = pd.read_csv(dataset)

# %%
autos
# Out:
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0      15.695714         0.0        0.0        0.0      19      0.0        0
# 1      29.964545         0.0        0.0        0.0       9      0.0        0
# 2      12.207778         0.0        0.0        0.0      23      0.0        0
# 3      29.964545         0.0        0.0        0.0      10      0.0        0
# 4      17.347895         0.0        0.0        0.0      17      0.0        0
# 5      14.982273         0.0        0.0        0.0      21      0.0        0
# 6      13.184400         0.0        0.0        0.0      22      0.0        0
# 7      13.733750         0.0        0.0        0.0      23      0.0        0
# 8      12.677308         0.0        0.0        0.0      23      0.0        0
# 9      13.184400         0.0        0.0        0.0      23      0.0        0
# ...          ...         ...        ...        ...     ...      ...      ...
# ...

# %%
# 41.144 filas y 83 columnas

# %%
autos.columns
# Out:
# Index(['barrels08', 'barrelsA08', 'charge120', 'charge240', 'city08',
#        'city08U', 'cityA08', 'cityA08U', 'cityCD', 'cityE', 'cityUF', 'co2',
#        'co2A', 'co2TailpipeAGpm', 'co2TailpipeGpm', 'comb08', 'comb08U',
#        'combA08', 'combA08U', 'combE', 'combinedCD', 'combinedUF', 'cylinders',
#        'displ', 'drive', 'engId', 'eng_dscr', 'feScore', 'fuelCost08',
#        'fuelCostA08', 'fuelType', 'fuelType1', 'ghgScore', 'ghgScoreA',
#        'highway08', 'highway08U', 'highwayA08', 'highwayA08U', 'highwayCD',
#        'highwayE', 'highwayUF', 'hlv', 'hpv', 'id', 'lv2', 'lv4', 'make',
#        'model', 'mpgData', 'phevBlended', 'pv2', 'pv4', 'range', 'rangeCity',
#        'rangeCityA', 'rangeHwy', 'rangeHwyA', 'trany', 'UCity', 'UCityA',
#        'UHighway', 'UHighwayA', 'VClass', 'year', 'youSaveSpend', 'guzzler',
#        'trans_dscr', 'tCharger', 'sCharger', 'atvType', 'fuelType2', 'rangeA',
#        'evMotor', 'mfrCode', 'c240Dscr', 'charge240b', 'c240bDscr',
# ...

# %% [markdown]
# # Tipos (*Types*)

# %%
cols = ['city08','comb08','highway08', 'cylinders','displ','drive','eng_dscr','fuelCost08','make','model','trany','range','createdOn','year']

# %%
autos[cols].dtypes
# Out:
# city08          int64
# comb08          int64
# highway08       int64
# cylinders     float64
# displ         float64
# drive          object
# eng_dscr       object
# fuelCost08      int64
# make           object
# model          object
# trany          object
# range           int64
# createdOn      object
# year            int64
# dtype: object

# %% [markdown]
# object no es sólo cuando es string, cuando hay muchos int y algunos nan también pandas pone object y eso ocupa ene memoria
# int8, int16, int32, etc son tipos de pandas/numpy pero no de python

# %%
#ahí están los límites
print (np.iinfo('int64'))
print (np.iinfo('int32'))
print (np.iinfo('int16'))
print (np.iinfo('int8'))
# Out:
# Machine parameters for int64
# ---------------------------------------------------------------
# min = -9223372036854775808
# max = 9223372036854775807
# ---------------------------------------------------------------
#
# Machine parameters for int32
# ---------------------------------------------------------------
# min = -2147483648
# max = 2147483647
# ---------------------------------------------------------------
#
# Machine parameters for int16
# ---------------------------------------------------------------
# min = -32768
# max = 32767
# ---------------------------------------------------------------
#
# Machine parameters for int8
# ---------------------------------------------------------------
# min = -128
# max = 127
# ---------------------------------------------------------------

# %%
#object ocupan ene memoria
autos[cols].memory_usage(deep=True)
# Out:
# Index             128
# city08         329152
# comb08         329152
# highway08      329152
# cylinders      329152
# displ          329152
# drive         3028369
# eng_dscr      2135693
# fuelCost08     329152
# make          2606267
# model         2813134
# trany         2933276
# range          329152
# createdOn     3497240
# year           329152
# dtype: int64

# %%
#object ocupan ene memoria
print (f"Memoria : {autos[cols].memory_usage(deep=True).sum()/1e6:.2f} Mb")
# Out:
# Memoria : 19.65 Mb

# %% [markdown]
# # Enteros (*int*)

# %%
autos[cols].select_dtypes(int).describe() #selecciona todos los que son int
# Out:
#              city08        comb08     highway08    fuelCost08         range  \
# count  41144.000000  41144.000000  41144.000000  41144.000000  41144.000000
# mean      18.369045     20.616396     24.504667   2362.335942      0.793506
# std        7.905886      7.674535      7.730364    654.981925     13.041592
# min        6.000000      7.000000      9.000000    500.000000      0.000000
# 25%       15.000000     17.000000     20.000000   1900.000000      0.000000
# 50%       17.000000     20.000000     24.000000   2350.000000      0.000000
# 75%       20.000000     23.000000     28.000000   2700.000000      0.000000
# max      150.000000    136.000000    124.000000   7400.000000    370.000000
#
#                year
# count  41144.000000
# mean    2001.535266
# std       11.142414
# min     1984.000000
# 25%     1991.000000
# 50%     2002.000000
# 75%     2011.000000
# max     2020.000000

# %%
#se puede escribir así también y es más claro
(autos
 [cols]
 .select_dtypes(int)
 .describe()    
)
# Out:
#              city08        comb08     highway08    fuelCost08         range  \
# count  41144.000000  41144.000000  41144.000000  41144.000000  41144.000000
# mean      18.369045     20.616396     24.504667   2362.335942      0.793506
# std        7.905886      7.674535      7.730364    654.981925     13.041592
# min        6.000000      7.000000      9.000000    500.000000      0.000000
# 25%       15.000000     17.000000     20.000000   1900.000000      0.000000
# 50%       17.000000     20.000000     24.000000   2350.000000      0.000000
# 75%       20.000000     23.000000     28.000000   2700.000000      0.000000
# max      150.000000    136.000000    124.000000   7400.000000    370.000000
#
#                year
# count  41144.000000
# mean    2001.535266
# std       11.142414
# min     1984.000000
# 25%     1991.000000
# 50%     2002.000000
# 75%     2011.000000
# max     2020.000000

# %% [markdown]
# El int64 parece que es medio exagerado para todos los casos

# %%
#city08 que es el city milleage va desde 6 a 150 ->int16
#comb08 combined milleafe va desde 7 a 136 ->int16
#highway va desde 9 a 124 -> int8 (es un pequeño riesgo porque está cerca)
#fuelcost08 va de 500 a 7400 -> int16
#range (de autos eléctricos) va de 0 a 370 ->int16
#year va de 1984 a 2020 ->int16

# %%
(
autos
[cols]
.astype({'highway08':'int8', 'city08':'int16','comb08':'int16'})
.select_dtypes([int,'int8']) 
.describe()   
)
# Out:
#           highway08    fuelCost08         range          year
# count  41144.000000  41144.000000  41144.000000  41144.000000
# mean      24.504667   2362.335942      0.793506   2001.535266
# std        7.730364    654.981925     13.041592     11.142414
# min        9.000000    500.000000      0.000000   1984.000000
# 25%       20.000000   1900.000000      0.000000   1991.000000
# 50%       24.000000   2350.000000      0.000000   2002.000000
# 75%       28.000000   2700.000000      0.000000   2011.000000
# max      124.000000   7400.000000    370.000000   2020.000000

# %%
#se ve bien parece mirando los números

# %%
(
autos
[cols]
.astype({'highway08':'int8', 'city08':'int16','comb08':'int16','fuelCost08':'int16','range':'int16','year':'int16'})
.select_dtypes(['integer']) #esto viene de numpy son todos los que parecen int
.describe()   
)
# Out:
#              city08        comb08     highway08    fuelCost08         range  \
# count  41144.000000  41144.000000  41144.000000  41144.000000  41144.000000
# mean      18.369045     20.616396     24.504667   2362.335942      0.793506
# std        7.905886      7.674535      7.730364    654.981925     13.041592
# min        6.000000      7.000000      9.000000    500.000000      0.000000
# 25%       15.000000     17.000000     20.000000   1900.000000      0.000000
# 50%       17.000000     20.000000     24.000000   2350.000000      0.000000
# 75%       20.000000     23.000000     28.000000   2700.000000      0.000000
# max      150.000000    136.000000    124.000000   7400.000000    370.000000
#
#                year
# count  41144.000000
# mean    2001.535266
# std       11.142414
# min     1984.000000
# 25%     1991.000000
# 50%     2002.000000
# 75%     2011.000000
# max     2020.000000

# %%
memoria = (
autos
[cols]
.astype({'highway08':'int8', 'city08':'int16','comb08':'int16','fuelCost08':'int16','range':'int16','year':'int16'})
.memory_usage(deep=True)
.sum()
)

print (f"Memoria: {memoria/1e6:.2f} Mb")
# Out:
# Memoria: 18.12 Mb

# %%
#bajamos 1Mb un poco más como 10%

# %% [markdown]
# # Floats

# %%
(
    autos
    [cols]
    .select_dtypes(['float'])
)
# Out:
#        cylinders  displ
# 0            4.0    2.0
# 1           12.0    4.9
# 2            4.0    2.2
# 3            8.0    5.2
# 4            4.0    2.2
# 5            4.0    1.8
# 6            4.0    1.8
# 7            4.0    1.6
# 8            4.0    1.6
# 9            4.0    1.8
# ...          ...    ...
# 41134        4.0    2.1
# 41135        4.0    1.9
# 41136        4.0    1.9
# 41137        4.0    1.9
# 41138        4.0    1.9
# 41139        4.0    2.2
# 41140        4.0    2.2
# 41141        4.0    2.2
# 41142        4.0    2.2
# 41143        4.0    2.2
#
# [41144 rows x 2 columns]

# %%
#cilindros se ve raro, debiera ser entero
#una forma es ver si hay nan
#count te tira los que no son nan
#por lo que si lo divido por la dimensión 0 y no es 100%, entonces hay nan

autos.cylinders.count()/autos.shape[0]
# Out:
# 0.9949931946334825

# %%
autos.cylinders.value_counts(dropna=False)
# Out:
# 4.0     15938
# 6.0     14284
# 8.0      8801
# 5.0       771
# 12.0      626
# 3.0       279
# NaN       206
# 10.0      170
# 2.0        59
# 16.0       10
# Name: cylinders, dtype: int64

# %% [markdown]
# Efectivamente hay 206 Nan, me imagino autos eléctricos o algo así

# %%
#probemos con query que la lleva
(
    autos
    [cols]
    .query('cylinders.isna()')
)
# Out:
#        city08  comb08  highway08  cylinders  displ              drive  \
# 7138       81      85         91        NaN    NaN                NaN
# 7139       81      72         64        NaN    NaN      2-Wheel Drive
# 8143       81      72         64        NaN    NaN      2-Wheel Drive
# 8144       74      65         58        NaN    NaN                NaN
# 8146       45      39         33        NaN    NaN      2-Wheel Drive
# 8147       84      75         66        NaN    NaN                NaN
# 9212       87      78         69        NaN    NaN      2-Wheel Drive
# 9213       45      39         33        NaN    NaN      2-Wheel Drive
# 10329      87      78         69        NaN    NaN      2-Wheel Drive
# 21413      22      24         28        NaN    NaN      4-Wheel Drive
# ...       ...     ...        ...        ...    ...                ...
# 34407      73      72         71        NaN    NaN  Front-Wheel Drive
# ...

# %% [markdown]
# parece mayormente que son los eléctricos

# %%
#agreguemos cylinders y displ poniendo un cero donde es nan
#además displ como float16
(
    autos
    [cols]
    .assign(cylinders=autos.cylinders.fillna(0).astype('int8'), disp=autos.displ.fillna(0))
    .astype({'highway08':'int8', 'city08':'int16','comb08':'int16','fuelCost08':'int16','range':'int16','year':'int16'})
    .describe()
)
# Out:
#              city08        comb08     highway08     cylinders         displ  \
# count  41144.000000  41144.000000  41144.000000  41144.000000  40940.000000
# mean      18.369045     20.616396     24.504667      5.688460      3.294238
# std        7.905886      7.674535      7.730364      1.797009      1.357151
# min        6.000000      7.000000      9.000000      0.000000      0.000000
# 25%       15.000000     17.000000     20.000000      4.000000      2.200000
# 50%       17.000000     20.000000     24.000000      6.000000      3.000000
# 75%       20.000000     23.000000     28.000000      6.000000      4.300000
# max      150.000000    136.000000    124.000000     16.000000      8.400000
#
#          fuelCost08         range          year          disp
# count  41144.000000  41144.000000  41144.000000  41144.000000
# mean    2362.335942      0.793506   2001.535266      3.277904
# std      654.981925     13.041592     11.142414      1.373415
# ...

# %%
#ya no perdemos data, bkn

#los floats en su gran dimension
print (np.finfo(np.float16))
print (np.finfo(np.float32))
print (np.finfo(np.float64))
# Out:
# Machine parameters for float16
# ---------------------------------------------------------------
# precision =   3   resolution = 1.00040e-03
# machep =    -10   eps =        9.76562e-04
# negep =     -11   epsneg =     4.88281e-04
# minexp =    -14   tiny =       6.10352e-05
# maxexp =     16   max =        6.55040e+04
# nexp =        5   min =        -max
# smallest_normal = 6.10352e-05   smallest_subnormal = 5.96046e-08
# ---------------------------------------------------------------
#
# Machine parameters for float32
# ---------------------------------------------------------------
# precision =   6   resolution = 1.0000000e-06
# machep =    -23   eps =        1.1920929e-07
# negep =     -24   epsneg =     5.9604645e-08
# minexp =   -126   tiny =       1.1754944e-38
# maxexp =    128   max =        3.4028235e+38
# nexp =        8   min =        -max
# smallest_normal = 1.1754944e-38   smallest_subnormal = 1.4012985e-45
# ...

# %%
memoria = (
    autos
    [cols]
    .assign(cylinders=autos.cylinders.fillna(0).astype('int8'), disp=autos.displ.fillna(0).astype('float16'))
    .astype({'highway08':'int8', 'city08':'int16','comb08':'int16','fuelCost08':'int16','range':'int16','year':'int16'})
    .memory_usage(deep=True)
    .sum()
)
print (f"Memoria: {memoria/1e6:.2f} Mb")
# Out:
# Memoria: 17.92 Mb

# %% [markdown]
# Ahorramos un poquito más, del orden de 2 Mb

# %%
#veamos la columna trany, se ve rara (transmisión)
autos.trany.value_counts(dropna=False)
# Out:
# Automatic 4-spd                     11047
# Manual 5-spd                         8361
# Automatic 3-spd                      3151
# Automatic (S6)                       3106
# Manual 6-spd                         2757
# Automatic 5-spd                      2203
# Automatic (S8)                       1665
# Automatic 6-spd                      1619
# Manual 4-spd                         1483
# Automatic (S5)                        833
# Automatic (variable gear ratios)      826
# Automatic 7-spd                       724
# Automatic 8-spd                       433
# Automatic (AM-S7)                     424
# Automatic (S7)                        327
# Automatic 9-spd                       293
# Automatic (AM7)                       245
# Automatic (S4)                        233
# Automatic (AV-S6)                     208
# Automatic (A1)                        201
# Automatic (AM6)                       151
# Automatic (AV-S7)                     139
# ...

# %%
#esto tiene dos datos, uno que es Automatico/Manual y otro las velocidades, entonces agreguemos una nueva columna que sean los automaticos.
# por otro lado el drive se ve que es como categórico
autos.drive.value_counts()
# Out:
# Front-Wheel Drive             14236
# Rear-Wheel Drive              13831
# 4-Wheel or All-Wheel Drive     6648
# All-Wheel Drive                3015
# 4-Wheel Drive                  1460
# 2-Wheel Drive                   507
# Part-time 4-Wheel Drive         258
# Name: drive, dtype: int64

# %%
#en cuales falta la transmision (drive)?
(
    autos
    [cols]
    .query('drive.isna()')
)
# Out:
#        city08  comb08  highway08  cylinders  displ drive            eng_dscr  \
# 7138       81      85         91        NaN    NaN   NaN                 NaN
# 8144       74      65         58        NaN    NaN   NaN                 NaN
# 8147       84      75         66        NaN    NaN   NaN                 NaN
# 18217      18      21         25        4.0    2.0   NaN               (FFS)
# 18218      20      22         26        4.0    1.5   NaN               (FFS)
# 18219      13      15         20        8.0    5.7   NaN      (350 V8) (FFS)
# 18220      13      15         20        8.0    5.7   NaN      (350 V8) (FFS)
# 18221      15      17         20        6.0    3.0   NaN          (FFS,TRBO)
# 18222      16      18         20        6.0    3.0   NaN               (FFS)
# 18223      16      18         22        6.0    3.0   NaN          (FFS,TRBO)
# ...       ...     ...        ...        ...    ...   ...                 ...
# ...

# %%
#sera que los viejos no tienen?
(autos
 [cols]
 .groupby('year')
 .drive
 .nunique())
# Out:
# year
# 1984    3
# 1985    4
# 1986    4
# 1987    3
# 1988    3
# 1989    3
# 1990    3
# 1991    3
# 1992    3
# 1993    3
# 1994    3
# 1995    4
# 1996    3
# 1997    4
# 1998    4
# 1999    4
# 2000    4
# 2001    4
# 2002    4
# 2003    4
# 2004    4
# 2005    4
# 2006    4
# 2007    4
# 2008    3
# 2009    4
# 2010    6
# 2011    5
# 2012    5
# 2013    5
# 2014    5
# 2015    5
# 2016    5
# 2017    5
# 2018    5
# 2019    5
# 2020    5
# Name: drive, dtype: int64

# %%
#parece que no, asumamos que los que no tienen drive (transmisión) son "Other" y chao

memoria = (
    autos
    [cols]
    .assign(cylinders=autos.cylinders.fillna(0).astype('int8'), 
            disp=autos.displ.fillna(0).astype('float16'),
            drive=autos.drive.fillna('Other').astype('category')) #categorizo porque son pocos
    .astype({'highway08':'int8', 'city08':'int16','comb08':'int16',
             'fuelCost08':'int16','range':'int16','year':'int16',
             'make':'category'}) #también la marca hagamosla como categoría, se que es un número limitado
    .memory_usage(deep=True)
    .sum()
)
print (f"Memoria: {memoria/1e6:.2f} Mb")
# Out:
# Memoria: 12.42 Mb

# %%
#seguimos bajando la memoria
#sobre la transmisión separemos los autos manuales porque trany dice si es Manual/Auto y el número de velocidades (lo vimos arriba)


memoria = (
    autos
    [cols]
    .assign(cylinders=autos.cylinders.fillna(0).astype('int8'), 
            disp=autos.displ.fillna(0).astype('float16'),
            drive=autos.drive.fillna('Other').astype('category'),
            automatic=autos.trany.str.contains('Auto'),                #boolean si es automático (simplismo) 
            speeds= autos.trany.str.extract(r'(\d)+').fillna(20).astype('int8'))    # regex que saca el número del texto, si no tiene asumo 20 (cualquier cosq)
    .astype({'highway08':'int8', 'city08':'int16','comb08':'int16',
             'fuelCost08':'int16','range':'int16','year':'int16',
             'make':'category'})
    .drop(columns=['trany'])  #ya no lo necesito
    .memory_usage(deep=True)
    .sum()
)
print (f"Memoria: {memoria/1e6:.2f} Mb")
# Out:
# Memoria: 10.96 Mb

# %% [markdown]
# # Fechas

# %%
autos[cols].createdOn.value_counts()
# Out:
# Tue Jan 01 00:00:00 EST 2013    34217
# Fri Jun 06 00:00:00 EDT 2014      100
# Thu Jul 07 00:00:00 EDT 2016      100
# Thu Jul 31 00:00:00 EDT 2014       95
# Wed Jun 13 00:00:00 EDT 2018       93
# Tue Sep 11 00:00:00 EDT 2018       87
# Tue Aug 02 00:00:00 EDT 2016       86
# Fri Aug 03 00:00:00 EDT 2018       86
# Thu Aug 03 00:00:00 EDT 2017       86
# Wed Apr 04 00:00:00 EDT 2018       84
#                                 ...
# Wed Apr 10 00:00:00 EDT 2019        1
# Mon Oct 13 00:00:00 EDT 2014        1
# Thu Mar 28 00:00:00 EDT 2019        1
# Tue Nov 15 00:00:00 EST 2016        1
# Mon Jan 12 00:00:00 EST 2015        1
# Mon Dec 03 00:00:00 EST 2018        1
# Wed Apr 25 00:00:00 EDT 2018        1
# Tue Mar 04 00:00:00 EST 2014        1
# Fri Feb 28 00:00:00 EST 2014        1
# Thu Jul 17 00:00:00 EDT 2014        1
# Name: createdOn, Length: 269, dtype: int64

# %%
#la fecha está en un formato medio raro, ese EDT no lo va a entender pandas (o no se como hacerlo)
# reemplazamos por la diferencia con GMT y pasamos a datetime

memoria = (
    autos
    [cols]
    .assign(cylinders=autos.cylinders.fillna(0).astype('int8'), 
            disp=autos.displ.fillna(0).astype('float16'),
            drive=autos.drive.fillna('Other').astype('category'),
            automatic=autos.trany.str.contains('Auto'),                #boolean si es automático (simplismo) 
            speeds= autos.trany.str.extract(r'(\d)+').fillna(20).astype('int8'),
            createdOn = pd.to_datetime(autos.createdOn.replace({' EDT': '-04:00', ' EST': '-05:00'}, regex=True)))    # regex que saca el número del texto, si no tiene asumo 20 (cualquier cosq)
    .astype({'highway08':'int8', 'city08':'int16','comb08':'int16',
             'fuelCost08':'int16','range':'int16','year':'int16',
             'make':'category'})
    .drop(columns=['trany'])  #ya no lo necesito
    .memory_usage(deep=True)
    .sum()
)
print (f"Memoria: {memoria/1e6:.2f} Mb")
# Out:
# Memoria: 9.77 Mb

# %%
#veamos engine description
autos.eng_dscr.value_counts(dropna=False)
# Out:
# NaN                                 16153
# (FFS)                                8827
# SIDI                                 5526
# (FFS) CA model                        926
# (FFS)      (MPFI)                     734
# FFV                                   701
# (FFS,TRBO)                            666
# (350 V8) (FFS)                        411
# (GUZZLER)  (FFS)                      366
# SOHC                                  354
#                                     ...
# B234L/R4 (FFS,TRBO)                     1
# GUZZLER V8 FFS,TURBO                    1
# 4.6M FFS MPFI                           1
# CNG FFS                                 1
# POLICE FFS MPFI                         1
# B308E5 FFS,TURBO                        1
# 5.4E-R FFS MPFI                         1
# V-6 FFS                                 1
# (GUZZLER)  (FFS)      (S-CHARGE)        1
# R-ENG (FFS,TRBO)                        1
# Name: eng_dscr, Length: 558, dtype: int64

# %%
#esto si supiera habría más trabajo, faltan 16 mil. para el ejercicio tomemos las que dicen FFS como indicador y chao pescao

memoria = (
    autos
    [cols]
    .assign(cylinders=autos.cylinders.fillna(0).astype('int8'), 
            disp=autos.displ.fillna(0).astype('float16'),
            drive=autos.drive.fillna('Other').astype('category'),
            automatic=autos.trany.str.contains('Auto'),                
            speeds= autos.trany.str.extract(r'(\d)+').fillna(20).astype('int8'),
            createdOn = pd.to_datetime(autos.createdOn.replace({' EDT': '-04:00', ' EST': '-05:00'}, regex=True)),
            ffs=autos.eng_dscr.str.contains('FFS'))    
    .astype({'highway08':'int8', 'city08':'int16','comb08':'int16',
             'fuelCost08':'int16','range':'int16','year':'int16',
             'make':'category'})
    .drop(columns=['trany','eng_dscr'])  #ya no lo necesito
    .memory_usage(deep=True)
    .sum()
)
print (f"Memoria: {memoria/1e6:.2f} Mb")
# Out:
# Memoria: 9.01 Mb

# %%
#ahora está lista la pega, lo reducimos a menos de la mitad
# cuando haces chaining es mejor después hacerlo con una función que se puede arreglar después y no llenar con cambios y cosas raras
# asi si tengo que hacer un cambio lo hago acpa y no miro ochocientas lineas

def tweak_autos(autos):
    cols = ['city08','comb08','highway08', 'cylinders','displ','drive','eng_dscr','fuelCost08','make','model','trany','range','createdOn','year']
    return (
    autos
    [cols]
    .assign(cylinders=autos.cylinders.fillna(0).astype('int8'), 
            disp=autos.displ.fillna(0).astype('float16'),
            drive=autos.drive.fillna('Other').astype('category'),
            automatic=autos.trany.str.contains('Auto'),                
            speeds= autos.trany.str.extract(r'(\d)+').fillna(20).astype('int8'),
            createdOn = pd.to_datetime(autos.createdOn.replace({' EDT': '-04:00', ' EST': '-05:00'}, regex=True)),
            ffs=autos.eng_dscr.str.contains('FFS'))    
    .astype({'highway08':'int8', 'city08':'int16','comb08':'int16',
             'fuelCost08':'int16','range':'int16','year':'int16',
             'make':'category'})
    .drop(columns=['trany','eng_dscr'])  #ya no lo necesito
    )

tweak_autos(autos) #voilá
# Out:
#        city08  comb08  highway08  cylinders  displ  \
# 0          19      21         25          4    2.0
# 1           9      11         14         12    4.9
# 2          23      27         33          4    2.2
# 3          10      11         12          8    5.2
# 4          17      19         23          4    2.2
# 5          21      22         24          4    1.8
# 6          22      25         29          4    1.8
# 7          23      24         26          4    1.6
# 8          23      26         31          4    1.6
# 9          23      25         30          4    1.8
# ...       ...     ...        ...        ...    ...
# 41134      18      20         24          4    2.1
# 41135      23      26         33          4    1.9
# 41136      21      24         30          4    1.9
# 41137      24      28         33          4    1.9
# 41138      21      25         32          4    1.9
# 41139      19      22         26          4    2.2
# ...

# %% [markdown]
# # Chain o Flow Programming
# Ev vez de usar variables intermedias uno ocupa el hecho de que la mayoría de las operaciones retornan un objeto y así se lee como una colección de recetas con pasos
#
# Si uno no encuentra la forma de hacer chain se puede usar .pipe

# %%
def tweak_autos(autos):
    cols = ['city08','comb08','highway08', 'cylinders','displ','drive','eng_dscr','fuelCost08','make','model','trany','range','createdOn','year']
    return (
    autos
    [cols]
    .assign(cylinders=autos.cylinders.fillna(0).astype('int8'), 
            disp=autos.displ.fillna(0).astype('float16'),
            drive=autos.drive.fillna('Other').astype('category'),
            automatic=autos.trany.str.contains('Auto'),                
            speeds= autos.trany.str.extract(r'(\d)+').fillna(20).astype('int8'),
            createdOn = pd.to_datetime(autos.createdOn.replace({' EDT': '-04:00', ' EST': '-05:00'}, regex=True)),
            ffs=autos.eng_dscr.str.contains('FFS'))    
    .astype({'highway08':'int8', 'city08':'int16','comb08':'int16',
             'fuelCost08':'int16','range':'int16','year':'int16',
             'make':'category'})
    .drop(columns=['trany','eng_dscr'])  #ya no lo necesito
    )

# %% [markdown]
# Comparemos con este desastre

# %%
a1 = autos[cols]
cyls=autos.cylinders.fillna(0)
cyls2=cyls.astype('int8')
a1['cylinders'] = cyls2
#ETC ETC ETC
# Out:
# /var/folders/w6/2grt96qn39vgm51r4hz21bz40000gn/T/ipykernel_2169/1905911837.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a1['cylinders'] = cyls2

# %% [markdown]
# Si necesitamos mostrar algo se puede hacer pipe

# %%
from IPython.display import display

def get_var(df, var_name):
    globals()[var_name] = df
    return df

def tweak_autos(autos):
    cols = ['city08','comb08','highway08', 'cylinders','displ','drive','eng_dscr','fuelCost08','make','model','trany','range','createdOn','year']
    return (
    autos
    [cols]
    .pipe(get_var,"df3") #crea variable df3 es un truco y puedo verlo como variable de paso intermedio
    .assign(cylinders=autos.cylinders.fillna(0).astype('int8'), 
            disp=autos.displ.fillna(0).astype('float16'),
            drive=autos.drive.fillna('Other').astype('category'),
            automatic=autos.trany.str.contains('Auto'),                
            speeds= autos.trany.str.extract(r'(\d)+').fillna(20).astype('int8'),
            createdOn = pd.to_datetime(autos.createdOn.replace({' EDT': '-04:00', ' EST': '-05:00'}, regex=True)),
            ffs=autos.eng_dscr.str.contains('FFS'))    
    .astype({'highway08':'int8', 'city08':'int16','comb08':'int16',
             'fuelCost08':'int16','range':'int16','year':'int16',
             'make':'category'})
    .drop(columns=['trany','eng_dscr'])  
    )

tweak_autos(autos)
df3 #acá está mostrando df3
# Out:
#        city08  comb08  highway08  cylinders  displ  \
# 0          19      21         25        4.0    2.0
# 1           9      11         14       12.0    4.9
# 2          23      27         33        4.0    2.2
# 3          10      11         12        8.0    5.2
# 4          17      19         23        4.0    2.2
# 5          21      22         24        4.0    1.8
# 6          22      25         29        4.0    1.8
# 7          23      24         26        4.0    1.6
# 8          23      26         31        4.0    1.6
# 9          23      25         30        4.0    1.8
# ...       ...     ...        ...        ...    ...
# 41134      18      20         24        4.0    2.1
# 41135      23      26         33        4.0    1.9
# 41136      21      24         30        4.0    1.9
# 41137      24      28         33        4.0    1.9
# 41138      21      25         32        4.0    1.9
# 41139      19      22         26        4.0    2.2
# ...

# %%
from IPython.display import display

def get_var(df, var_name):
    globals()[var_name] = df
    return df

def tweak_autos(autos):
    cols = ['city08','comb08','highway08', 'cylinders','displ','drive','eng_dscr','fuelCost08','make','model','trany','range','createdOn','year']
    return (
    autos
    [cols]
    .pipe(get_var,"df3") #crea variable df3 es un truco
    .assign(cylinders=autos.cylinders.fillna(0).astype('int8'), 
            disp=autos.displ.fillna(0).astype('float16'),
            drive=autos.drive.fillna('Other').astype('category'),
            automatic=autos.trany.str.contains('Auto'),                
            speeds= autos.trany.str.extract(r'(\d)+').fillna(20).astype('int8'),
            createdOn = pd.to_datetime(autos.createdOn.replace({' EDT': '-04:00', ' EST': '-05:00'}, regex=True)),
            ffs=autos.eng_dscr.str.contains('FFS'))
    .pipe(lambda df:display(df) or df) #esto es para debug y display es para notebook y lo muestra 
    #jupyter por defecto solo muestra el ultimo paso esto permite ver el intermedio   
    .astype({'highway08':'int8', 'city08':'int16','comb08':'int16',
             'fuelCost08':'int16','range':'int16','year':'int16',
             'make':'category'})
    .drop(columns=['trany','eng_dscr'])  
    )

tweak_autos(autos)
# Out:
#        city08  comb08  highway08  cylinders  displ  \
# 0          19      21         25          4    2.0
# 1           9      11         14         12    4.9
# 2          23      27         33          4    2.2
# 3          10      11         12          8    5.2
# 4          17      19         23          4    2.2
# 5          21      22         24          4    1.8
# 6          22      25         29          4    1.8
# 7          23      24         26          4    1.6
# 8          23      26         31          4    1.6
# 9          23      25         30          4    1.8
# ...       ...     ...        ...        ...    ...
# 41134      18      20         24          4    2.1
# 41135      23      26         33          4    1.9
# 41136      21      24         30          4    1.9
# 41137      24      28         33          4    1.9
# 41138      21      25         32          4    1.9
# 41139      19      22         26          4    2.2
# ...

# %% [markdown]
# También puedo comentar una linea y ver como se mueve, de a poco y no pasa nada

# %% [markdown]
# # Don't mutate
# Esto es cuando uno uso inplace=True
# * No hay beneficios de rendimiento
# * No se puede hacer chaining
# * SettingWithCopyWarning fun

# %% [markdown]
# # Don't Apply
# Apply es básicamente un loop, es mega lento

# %%
def tweak_autos(autos):
    cols = ['city08','comb08','highway08', 'cylinders','displ','drive','eng_dscr','fuelCost08','make','model','trany','range','createdOn','year']
    return (
    autos
    [cols]
    .assign(cylinders=autos.cylinders.fillna(0).astype('int8'), 
            disp=autos.displ.fillna(0).astype('float16'),
            drive=autos.drive.fillna('Other').astype('category'),
            automatic=autos.trany.str.contains('Auto'),                
            speeds= autos.trany.str.extract(r'(\d)+').fillna(20).astype('int8'),
            createdOn = pd.to_datetime(autos.createdOn.replace({' EDT': '-04:00', ' EST': '-05:00'}, regex=True)),
            ffs=autos.eng_dscr.str.contains('FFS'))
    .astype({'highway08':'int8', 'city08':'int16','comb08':'int16',
             'fuelCost08':'int16','range':'int16','year':'int16',
             'make':'category'})
    .drop(columns=['trany','eng_dscr'])  
    )

# %%
#tratemos de ver el ahorro en litros/100 kms
def to_lper100km(val):
    return 235.215/val

autos2 = tweak_autos(autos)

# %%
# %timeit autos2.city08.apply(to_lper100km)
# Out:
# 4.43 ms ± 14.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
#esto da el mismo resultado
# %timeit 235.215/autos2.city08
# Out:
# 44.9 µs ± 179 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
#es mucho más rápido, casi 100 veces en este caso

# %%
def is_american(val):
    return val  in {'Chevrolet', 'Ford','Dodge', 'GMC', 'Tesla'}

# %%
# %%timeit
autos2.make.apply(is_american)
# Out:
# 166 µs ± 1.85 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %%timeit
autos2.make.isin({'Chevrolet', 'Ford','Dodge', 'GMC', 'Tesla'})
# Out:
# 372 µs ± 3.74 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %%timeit
#strings en pandas no son muy optimizadas entonces las string operations son lentos
autos2.make.astype(str).isin({'Chevrolet', 'Ford','Dodge', 'GMC', 'Tesla'})
# Out:
# 5.17 ms ± 49.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
def country(val):
    if val in {'Chevrolet', 'Ford','Dodge', 'GMC', 'Tesla'}:
        return 'US'
    return 'Other'

# %%
# %%timeit
(autos2
 .assign(country=autos2.make.apply(country))
 )
# Out:
# 3.13 ms ± 71.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
values = {'Chevrolet', 'Ford','Dodge', 'GMC', 'Tesla'}
(autos2
 .assign(country='US')
 .assign(country=lambda df_:df_.country.where(df_.make.isin(values),'Other'))
 )
# Out:
# 7.35 ms ± 58 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
#where sirve pero es medio extraño cuando hay muchas variables o ifs
#acá es más lento por los strings

# %%
# %%timeit
values = {'Chevrolet', 'Ford','Dodge', 'GMC', 'Tesla'}

#una buena opcion es usar np.select
(autos2
 .assign(country=np.select([autos2.make.isin(values)],['US'],'Other'))
 )
# Out:
# 4.89 ms ± 50.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# # Master Aggregation
# Consumo por país por año?

# %%
(
    autos2
    .groupby('year')
    [['comb08','speeds']]
    .mean()
)
# Out:
#          comb08    speeds
# year
# 1984  19.881874  3.928208
# 1985  19.808348  3.924750
# 1986  19.550413  3.984298
# 1987  19.228549  4.037690
# 1988  19.328319  4.129204
# 1989  19.125759  4.166522
# 1990  19.000928  4.238404
# 1991  18.825972  4.301237
# 1992  18.862623  4.318466
# 1993  19.104300  4.339433
# 1994  19.012220  4.332994
# 1995  18.797311  4.356774
# 1996  19.584735  4.364812
# 1997  19.429134  4.402887
# 1998  19.518473  4.419951
# 1999  19.611502  4.421362
# 2000  19.526190  4.508333
# 2001  19.479693  4.660812
# 2002  19.168205  4.757949
# 2003  19.000958  4.911877
# 2004  19.067736  4.976827
# 2005  19.193825  5.192110
# 2006  18.959239  5.315217
# 2007  18.978686  5.610124
# 2008  19.276327  5.773378
# 2009  19.735642  6.043074
# 2010  20.588819  6.271416
# 2011  21.011504  6.560177
# 2012  21.819444  6.706597
# 2013  23.125000  6.896959
# 2014  23.531429  6.985306
# 2015  24.038971  7.035853
# 2016  25.150555  7.080032
# 2017  25.249033  7.225058
# ...

# %%
# %%timeit
##ojo con el orden
(
    autos2
    .groupby('year')
    [['comb08','speeds']]
    .mean()
)
# Out:
# 1.17 ms ± 31.7 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %%timeit
(
    autos2
    .groupby('year')
    .mean(numeric_only=True)
    [['comb08','speeds']]
    
)
# Out:
# 3.54 ms ± 495 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
#calcula todos los promedio de todas las columnas y después agrupa así que es medio lento

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
(
    autos2
    .groupby('year')
    [['comb08','speeds']]
    .mean()
    .plot()
)
# Out:
# <AxesSubplot: xlabel='year'>

# %%
(
    autos2
    .groupby('year')
    [['comb08','speeds']]
    #.median()
    .quantile(.1)
    .plot()
)
# Out:
# <AxesSubplot: xlabel='year'>

# %%
# agregar pais

(
    autos2
    .assign(country=autos2.make.apply(country))
    .groupby(['year','country'])
    .mean(numeric_only=True)
)
# Out:
#                  city08     comb08  highway08  cylinders     displ  \
# year country
# 1984 Other    19.384615  21.417330  24.847038   4.908046  2.690539
#      US       16.079232  17.797119  20.669868   6.033613  3.809364
# 1985 Other    19.284768  21.373068  24.816777   4.871965  2.641925
#      US       16.275472  18.025157  21.020126   5.949686  3.765912
# 1986 Other    19.167183  21.213622  24.650155   4.804954  2.536223
#      US       15.945035  17.645390  20.464539   6.136525  3.925532
# 1987 Other    18.633381  20.710414  24.186876   4.825963  2.583167
#      US       15.611722  17.326007  20.208791   6.164835  3.932601
# 1988 Other    18.668224  20.814642  24.437695   4.819315  2.531464
#      US       15.577869  17.372951  20.420082   6.307377  4.067828
# ...                 ...        ...        ...        ...       ...
# 2016 Other    21.903749  24.439716  28.866261   5.493414  3.022927
#      US       25.061818  27.701818  32.265455   5.356364  3.534510
# ...

# %%
#multiplos agregados
def second_to_last(ser):
    return ser.iloc[-2]

(
    autos2
    .assign(country=autos2.make.apply(country))
    .groupby(['year','country'])
    .agg(['min','mean', second_to_last])
)
# Out:
# /var/folders/w6/2grt96qn39vgm51r4hz21bz40000gn/T/ipykernel_2169/1343665272.py:9: FutureWarning: ['drive', 'make', 'model', 'createdOn'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   .agg(['min','mean', second_to_last])
#              city08                           comb08             \
#                 min       mean second_to_last    min       mean
# year country
# 1984 Other        7  19.384615             14      8  21.417330
#      US           8  16.079232             15      9  17.797119
# 1985 Other        7  19.284768             19      8  21.373068
#      US           8  16.275472             14     10  18.025157
# 1986 Other        6  19.167183             10      7  21.213622
#      US           9  15.945035             16     10  17.645390
# 1987 Other        6  18.633381             12      7  20.710414
# ...

# %%
(
    autos2
    .assign(country=autos2.make.apply(country))
    .groupby(['year','country'])
    .mean()
    .plot()
)
# Out:
# /var/folders/w6/2grt96qn39vgm51r4hz21bz40000gn/T/ipykernel_2169/1317386616.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   .mean()
# <AxesSubplot: xlabel='year,country'>

# %%
(
    autos2
    .assign(country=autos2.make.apply(country))
    .groupby(['year','country'])
    .mean(numeric_only=True)
    .unstack() # innermost index lo rotamos y pasa a columna (country)
)
# Out:
#             city08                comb08             highway08             \
# country      Other         US      Other         US      Other         US
# year
# 1984     19.384615  16.079232  21.417330  17.797119  24.847038  20.669868
# 1985     19.284768  16.275472  21.373068  18.025157  24.816777  21.020126
# 1986     19.167183  15.945035  21.213622  17.645390  24.650155  20.464539
# 1987     18.633381  15.611722  20.710414  17.326007  24.186876  20.208791
# 1988     18.668224  15.577869  20.814642  17.372951  24.437695  20.420082
# 1989     18.533040  15.139831  20.662261  16.908898  24.252570  19.887712
# 1990     18.510109  14.850575  20.640747  16.577011  24.267496  19.485057
# 1991     18.087943  14.803279  20.174468  16.599532  23.809929  19.683841
# 1992     17.915374  14.895631  20.098731  16.735437  23.820874  20.063107
# 1993     18.084866  15.007772  20.309760  16.896373  24.172560  20.230570
# 1994     18.046474  14.952514  20.264423  16.829609  24.173077  20.201117
# ...

# %%
(
    autos2
    .assign(country=autos2.make.apply(country))
    .groupby(['year','country'])
    .mean(numeric_only=True)
    .unstack()
    .city08
    .plot()
    .legend(bbox_to_anchor=(1,1))
)

# %%
#suavizamos la curva con un rolling
(
    autos2
    .assign(country=autos2.make.apply(country))
    .groupby(['year','country'])
    .mean(numeric_only=True)
    .unstack()
    .city08
    .rolling(5)
    .mean()
    .plot()
    .legend(bbox_to_anchor=(1,1))
)
